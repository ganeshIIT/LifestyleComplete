# %% [markdown]
# <a href="https://colab.research.google.com/github/ganeshIIT/airbnb/blob/master/airbnb_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyodbc -q

# !curl https://packages.microsoft.com/keys/microsoft.asc | apt-key add -
# !curl https://packages.microsoft.com/config/ubuntu/16.04/prod.list > /etc/apt/sources.list.d/mssql-release.list
# !sudo apt-get update
# !sudo ACCEPT_EULA=Y apt-get -q -y install msodbcsql17

# %%
import re

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pyodbc

import helper
import dataloader

# %%
plt.style.use('seaborn')
# Out:
# /var/folders/74/ndv7v28d3078l2cq22t43pkc0000gn/T/ipykernel_66283/240305066.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
cstring = helper.get_connstring()
with pyodbc.connect(cstring) as conn:
    query = "SELECT * from dayMerged"
    df = pd.read_sql(query, conn, index_col='id')
# Out:
# /var/folders/74/ndv7v28d3078l2cq22t43pkc0000gn/T/ipykernel_66283/2662067844.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn, index_col='id')

# %%
df.columns
# Out:
# Index(['creationdate', 'BodyMassIndex', 'Height', 'BodyMass', 'HeartRate',
#        'RespiratoryRate', 'BodyFatPercentage', 'LeanBodyMass',
#        'RestingHeartRate', 'VO2Max', 'WalkingHeartRateAverage',
#        'EnvironmentalAudioExposure', 'HeadphoneAudioExposure',
#        'WalkingDoubleSupportPercentage', 'SixMinuteWalkTestDistance',
#        'WalkingSpeed', 'WalkingStepLength', 'WalkingAsymmetryPercentage',
#        'HKDataTypeSleepDurationGoal', 'AppleWalkingSteadiness', 'hrvstd',
#        'StepCount', 'DistanceWalkingRunning', 'BasalEnergyBurned',
#        'ActiveEnergyBurned', 'FlightsClimbed', 'AppleExerciseTime',
#        'AppleStandTime', 'fromdate', 'todate', 'bedtime', 'waketime', 'inbed',
#        'awake', 'fellasleepin', 'sessions', 'asleep', 'efficiency', 'quality',
#        'deep', 'sleepbpm', 'daybpm', 'wakingbpm', 'hrv', 'sleephrv', 'respavg',
#        'respmin', 'respmax', 'duration', 'totaldistance', 'totalenergyburned',
#        'min_HeartRate', 'min_HeartRateVariabilitySDNN', 'max_HeartRate',
#        'max_HeartRateVariabilitySDNN'],
#       dtype='object')

# %%
df.head()
# Out:
#    creationdate  BodyMassIndex  Height   BodyMass  HeartRate  RespiratoryRate  \
# id
# 1    2020-01-03           27.0   181.0  89.000000  72.473821        16.280488
# 2    2020-03-07           27.0   181.0  89.000000  72.473821        16.280488
# 3    2020-03-08           27.0   181.0  89.000000  72.473821        16.280488
# 4    2021-07-27           27.0   181.0  89.000000  72.473821        16.280488
# 5    2021-07-28           27.0   181.0  88.916667  72.473821        16.280488
#
#     BodyFatPercentage  LeanBodyMass  RestingHeartRate  VO2Max  ...  respavg  \
# id                                                             ...
# 1               0.172        73.278              67.0   31.38  ...      NaN
# 2               0.172        73.278              67.0   31.38  ...      NaN
# 3               0.172        73.278              67.0   31.38  ...      NaN
# 4               0.172        73.278              67.0   31.38  ...      NaN
# 5               0.172        73.278              67.0   31.38  ...      NaN
#
#     respmin  respmax  duration  totaldistance  totalenergyburned  \
# id
# 1       NaN      NaN       NaN            NaN                NaN
# 2       NaN      NaN       NaN            NaN                NaN
# 3       NaN      NaN       NaN            NaN                NaN
# 4       NaN      NaN       NaN            NaN                NaN
# 5       NaN      NaN       NaN            NaN                NaN
#
#     min_HeartRate  min_HeartRateVariabilitySDNN  max_HeartRate  \
# id
# 1             NaN                           NaN            NaN
# 2             NaN                           NaN            NaN
# 3             NaN                           NaN            NaN
# 4             NaN                           NaN            NaN
# 5             NaN                           NaN            NaN
#
#     max_HeartRateVariabilitySDNN
# id
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# 5                            NaN
#
# [5 rows x 55 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 371 entries, 1 to 371
# Data columns (total 55 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   creationdate                    371 non-null    object
#  1   BodyMassIndex                   371 non-null    float64
#  2   Height                          371 non-null    float64
#  3   BodyMass                        371 non-null    float64
#  4   HeartRate                       371 non-null    float64
#  5   RespiratoryRate                 371 non-null    float64
#  6   BodyFatPercentage               371 non-null    float64
#  7   LeanBodyMass                    371 non-null    float64
#  8   RestingHeartRate                371 non-null    float64
#  9   VO2Max                          371 non-null    float64
#  10  WalkingHeartRateAverage         318 non-null    float64
#  11  EnvironmentalAudioExposure      334 non-null    float64
#  12  HeadphoneAudioExposure          333 non-null    float64
#  13  WalkingDoubleSupportPercentage  292 non-null    float64
#  14  SixMinuteWalkTestDistance       32 non-null     float64
#  15  WalkingSpeed                    307 non-null    float64
#  16  WalkingStepLength               307 non-null    float64
#  17  WalkingAsymmetryPercentage      94 non-null     float64
#  18  HKDataTypeSleepDurationGoal     3 non-null      float64
#  19  AppleWalkingSteadiness          46 non-null     float64
#  20  hrvstd                          371 non-null    float64
#  21  StepCount                       337 non-null    float64
#  22  DistanceWalkingRunning          346 non-null    float64
#  23  BasalEnergyBurned               337 non-null    float64
#  24  ActiveEnergyBurned              335 non-null    float64
#  25  FlightsClimbed                  105 non-null    float64
#  26  AppleExerciseTime               279 non-null    float64
#  27  AppleStandTime                  334 non-null    float64
#  28  fromdate                        371 non-null    object
#  29  todate                          371 non-null    object
#  30  bedtime                         371 non-null    object
#  31  waketime                        371 non-null    object
#  32  inbed                           332 non-null    float64
#  33  awake                           332 non-null    float64
#  34  fellasleepin                    330 non-null    float64
#  35  sessions                        332 non-null    float64
#  36  asleep                          332 non-null    float64
#  37  efficiency                      332 non-null    float64
#  38  quality                         330 non-null    float64
#  39  deep                            282 non-null    float64
#  40  sleepbpm                        330 non-null    float64
#  41  daybpm                          329 non-null    float64
#  42  wakingbpm                       332 non-null    float64
#  43  hrv                             332 non-null    float64
#  44  sleephrv                        330 non-null    float64
#  45  respavg                         330 non-null    float64
#  46  respmin                         330 non-null    float64
#  47  respmax                         330 non-null    float64
#  48  duration                        336 non-null    float64
#  49  totaldistance                   336 non-null    float64
#  50  totalenergyburned               336 non-null    float64
#  51  min_HeartRate                   335 non-null    float64
#  52  min_HeartRateVariabilitySDNN    334 non-null    float64
#  53  max_HeartRate                   335 non-null    float64
#  54  max_HeartRateVariabilitySDNN    334 non-null    float64
# dtypes: float64(50), object(5)
# memory usage: 162.3+ KB

# %%
df.describe().T
# Out:
#                                 count          mean          std  \
# BodyMassIndex                   371.0     25.293396     0.550480
# Height                          371.0    181.000000     0.000000
# BodyMass                        371.0     82.782240     1.820842
# HeartRate                       371.0     90.452267    13.652601
# RespiratoryRate                 371.0     16.401907     0.826168
# BodyFatPercentage               371.0      0.153635     0.006022
# LeanBodyMass                    371.0     70.107208     1.025402
# RestingHeartRate                371.0     67.902291     4.317767
# VO2Max                          371.0     34.453538     1.642773
# WalkingHeartRateAverage         318.0     95.113208     8.680206
# EnvironmentalAudioExposure      334.0     56.463486     2.508356
# HeadphoneAudioExposure          333.0     54.802070    11.346567
# WalkingDoubleSupportPercentage  292.0      0.308722     0.011604
# SixMinuteWalkTestDistance        32.0    463.625000    55.093323
# WalkingSpeed                    307.0      3.255751     0.613234
# WalkingStepLength               307.0     57.235315     6.637747
# WalkingAsymmetryPercentage       94.0      0.030266     0.124205
# HKDataTypeSleepDurationGoal       3.0      8.333333     0.577350
# AppleWalkingSteadiness           46.0      0.709613     0.133740
# hrvstd                          371.0     44.221222     7.424406
# StepCount                       337.0  11383.210682  4654.022581
# DistanceWalkingRunning          346.0      8.783183     3.720678
# BasalEnergyBurned               337.0   1942.041119   224.878785
# ActiveEnergyBurned              335.0    585.762991   158.693845
# FlightsClimbed                  105.0      7.104762     5.709176
# AppleExerciseTime               279.0     47.842294    26.208973
# AppleStandTime                  334.0    157.497006    42.498384
# inbed                           332.0  26828.674699  5609.234460
# awake                           332.0   2212.771084  3068.132397
# fellasleepin                    330.0      0.000000     0.000000
# sessions                        332.0      1.250000     0.440578
# asleep                          332.0  24615.903614  4685.326593
# efficiency                      332.0     92.486145     9.573351
# quality                         330.0  18129.993939  3392.410017
# deep                            282.0   3991.024823  2146.529795
# sleepbpm                        330.0     66.633636     5.258323
# daybpm                          329.0     78.742857     3.473351
# wakingbpm                       332.0     66.035241     5.492983
# hrv                             332.0     70.879518    25.476082
# sleephrv                        330.0     55.909091    14.995366
# respavg                         330.0     15.856667     0.790310
# respmin                         330.0     13.166667     0.856467
# respmax                         330.0     19.992424     1.978018
# duration                        336.0     22.906296    19.752819
# totaldistance                   336.0      0.221850     0.755789
# totalenergyburned               336.0    234.670507   378.608630
# min_HeartRate                   335.0     51.808592     6.562521
# min_HeartRateVariabilitySDNN    334.0     21.629795     6.570840
# max_HeartRate                   335.0    146.233866    22.153217
# max_HeartRateVariabilitySDNN    334.0     79.001070    24.476358
#
#                                          min           25%           50%  \
# BodyMassIndex                      24.200000     25.091667     25.350000
# Height                            181.000000    181.000000    181.000000
# BodyMass                           79.400000     82.141667     82.883400
# HeartRate                          66.086795     75.198118     94.012723
# RespiratoryRate                    13.500000     15.834285     16.280488
# BodyFatPercentage                   0.142000      0.151417      0.154500
# LeanBodyMass                       68.125200     69.714362     70.218000
# RestingHeartRate                   56.000000     65.000000     67.000000
# VO2Max                             31.380000     34.015000     35.360000
# WalkingHeartRateAverage            74.000000     90.000000     93.500000
# EnvironmentalAudioExposure         43.876507     55.041662     56.191802
# HeadphoneAudioExposure              0.000000     46.990040     54.215600
# WalkingDoubleSupportPercentage      0.275286      0.301612      0.310225
# SixMinuteWalkTestDistance         340.000000    433.750000    500.000000
# WalkingSpeed                        1.608000      2.799900      3.178286
# WalkingStepLength                  36.500000     52.679487     56.333333
# WalkingAsymmetryPercentage          0.000000      0.000000      0.000000
# HKDataTypeSleepDurationGoal         8.000000      8.000000      8.000000
# AppleWalkingSteadiness              0.506641      0.605489      0.697196
# hrvstd                             20.081700     38.968926     44.323629
# StepCount                          74.000000   7927.000000  10369.000000
# DistanceWalkingRunning              0.060687      6.229619      8.214778
# BasalEnergyBurned                 289.376000   1915.508000   1959.188000
# ActiveEnergyBurned                 14.522000    493.708000    598.077000
# FlightsClimbed                      1.000000      3.000000      6.000000
# AppleExerciseTime                   1.000000     26.000000     47.000000
# AppleStandTime                      1.000000    132.250000    158.500000
# inbed                           14640.000000  22740.000000  26160.000000
# awake                               0.000000      0.000000    660.000000
# fellasleepin                        0.000000      0.000000      0.000000
# sessions                            1.000000      1.000000      1.000000
# asleep                          10980.000000  21645.000000  24300.000000
# efficiency                         62.600000     86.975000     97.150000
# quality                          7082.000000  15895.000000  17892.000000
# deep                              840.000000   2651.250000   3700.500000
# sleepbpm                           55.700000     62.900000     66.050000
# daybpm                             71.300000     76.200000     78.800000
# wakingbpm                          43.000000     62.000000     65.000000
# hrv                                23.000000     53.000000     66.000000
# sleephrv                           23.000000     46.000000     54.000000
# respavg                            14.300000     15.300000     15.700000
# respmin                            11.000000     12.500000     13.000000
# respmax                            16.000000     18.500000     19.500000
# duration                            0.000000      0.000000     21.435123
# totaldistance                       0.000000      0.000000      0.000000
# totalenergyburned                   0.000000      0.000000    154.007500
# min_HeartRate                      40.000000     48.000000     52.000000
# min_HeartRateVariabilitySDNN        7.401440     17.225550     20.765300
# max_HeartRate                      84.000000    133.000000    154.000000
# max_HeartRateVariabilitySDNN       22.976900     62.611850     75.016200
#
#                                          75%           max
# BodyMassIndex                      25.500000     27.000000
# Height                            181.000000    181.000000
# BodyMass                           83.483695     89.000000
# HeartRate                         102.109525    117.760000
# RespiratoryRate                    16.903525     20.159574
# BodyFatPercentage                   0.156000      0.172000
# LeanBodyMass                       70.541042     73.278000
# RestingHeartRate                   71.000000     85.000000
# VO2Max                             35.538732     38.790000
# WalkingHeartRateAverage            98.000000    132.000000
# EnvironmentalAudioExposure         57.342212     64.239104
# HeadphoneAudioExposure             62.862262     84.762100
# WalkingDoubleSupportPercentage      0.317000      0.340000
# SixMinuteWalkTestDistance         500.000000    500.000000
# WalkingSpeed                        3.701000      4.888421
# WalkingStepLength                  61.872222     74.473684
# WalkingAsymmetryPercentage          0.010000      0.900000
# HKDataTypeSleepDurationGoal         8.500000      9.000000
# AppleWalkingSteadiness              0.745858      1.000000
# hrvstd                             49.484150     70.808833
# StepCount                       14552.000000  25383.000000
# DistanceWalkingRunning             11.422945     19.727312
# BasalEnergyBurned                1992.803000   3763.694000
# ActiveEnergyBurned                671.496500   1221.506000
# FlightsClimbed                     10.000000     37.000000
# AppleExerciseTime                  67.500000    118.000000
# AppleStandTime                    185.000000    335.000000
# inbed                           30720.000000  53100.000000
# awake                            3795.000000  17940.000000
# fellasleepin                        0.000000      0.000000
# sessions                            1.000000      3.000000
# asleep                          27600.000000  53100.000000
# efficiency                        100.000000    100.000000
# quality                         20178.750000  35931.000000
# deep                             5424.500000  12768.000000
# sleepbpm                           69.925000     91.900000
# daybpm                             81.100000     89.600000
# wakingbpm                          69.000000     85.000000
# hrv                                84.000000    211.000000
# sleephrv                           64.000000    107.000000
# respavg                            16.375000     20.500000
# respmin                            13.500000     15.500000
# respmax                            21.000000     32.000000
# duration                           33.000947     97.238595
# totaldistance                       0.000000      5.493654
# totalenergyburned                 243.429109   2927.468000
# min_HeartRate                      56.000000    117.760000
# min_HeartRateVariabilitySDNN       25.515625     53.241800
# max_HeartRate                     163.000000    184.000000
# max_HeartRateVariabilitySDNN       91.357125    210.672000
